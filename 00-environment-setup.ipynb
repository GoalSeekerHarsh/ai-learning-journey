# %%
# Environment Setup Verification
# Date: October 19, 2025
# Author: Harsh

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import platform
import sys

print("=" * 50)
print("🎉 AI LEARNING ENVIRONMENT VERIFICATION")
print("=" * 50)

print(f"\n📍 Python Version: {sys.version.split()[0]}")
print(f"📍 Architecture: {platform.machine()}")
print(f"📍 Processor: {platform.processor()}")

print("\n📚 Library Versions:")
print(f"   • NumPy: {np.__version__}")
print(f"   • Pandas: {pd.__version__}")
print(f"   • Matplotlib: {plt.matplotlib.__version__}")
print(f"   • Scikit-learn: {sklearn.__version__}")

print("\n✅ Environment is ready for AI/ML development!")
print("=" * 50)

# Quick test: Create and visualize a simple array
test_array = np.array([1, 2, 3, 4, 5])
print(f"\n🧪 Quick Test:")
print(f"   Array: {test_array}")
print(f"   Mean: {test_array.mean()}")
print(f"   Sum: {test_array.sum()}")

# Simple visualization test
plt.figure(figsize=(6, 4))
plt.plot(test_array, test_array**2, 'b-o', linewidth=2, markersize=8)
plt.title('Environment Test: y = x²', fontsize=14, fontweight='bold')
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\n🚀 You're ready to start your AI journey!")
# Out:
# ...
# 🎉 AI LEARNING ENVIRONMENT VERIFICATION
# ...
#
# 📍 Python Version: 3.11.13
# 📍 Architecture: arm64
# 📍 Processor: arm
#
# 📚 Library Versions:
#    • NumPy: 2.3.3
#    • Pandas: 2.3.3
#    • Matplotlib: 3.10.6
#    • Scikit-learn: 1.7.2
#
# ✅ Environment is ready for AI/ML development!
# ...
#
# 🧪 Quick Test:
#    Array: [1 2 3 4 5]
#    Mean: 3.0
#    Sum: 15
# 🚀 You're ready to start your AI journey!
